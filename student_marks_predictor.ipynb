# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Hours": [1,2,3,4,5,6,7,8],
    "Marks": [20,30,40,50,60,70,80,90]
}

df = pd.DataFrame(data)

X = df[["Hours"]]
y = df["Marks"]

model = LinearRegression()
model.fit(X,y)

test_data = pd.DataFrame({'Hours': [5]})
print("Marks for 5 hours study =", model.predict(test_data))

plt.scatter(X,y)
plt.plot(X,model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Marks Prediction")
plt.show()
# Out:
# Marks for 5 hours study = [60.]
